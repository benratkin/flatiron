# %% [markdown]
# # Interactions - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll explore interactions in the Boston Housing dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Implement interaction terms in Python using the `sklearn` and `statsmodels` packages
# - Interpret interaction variables in the context of a real-world problem

# %% [markdown]
# ## Build a baseline model

# %% [markdown]
# You'll use a couple of built-in functions, which we imported for you below:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the Boston data set using `load_boston()`. We won't bother to preprocess the data in this lab. If you still want to build a model in the end, you can do that, but this lab will just focus on finding meaningful insights in interactions and how they can improve $R^2$ values.

# %%
regression = LinearRegression()
boston = load_boston()

df = pd.DataFrame(data=boston.data, columns=boston.feature_names)
y = boston.target

# %% [markdown]
# Create a baseline model which includes all the variables in the Boston housing data set to predict the house prices. Then use 10-fold cross-validation and report the mean $R^2$ value as the baseline $R^2$.

# %%
cross_val_gen = KFold(n_splits=10, shuffle=True, random_state=1)
baseline_r2 = np.mean(cross_val_score(regression, df, y, cv=cross_val_gen, scoring='r2'))

# %% [markdown]
# ## See how interactions improve your baseline

# %% [markdown]
# Next, create all possible combinations of interactions, loop over them and add them to the baseline model one by one to see how they affect the $R^2$. We'll look at the 3 interactions which have the biggest effect on our $R^2$, so print out the top 3 combinations.
#
# You will create a `for` loop to loop through all the combinations of 2 predictors. You can use `combinations` from itertools to create a list of all the pairwise combinations. To find more info on how this is done, have a look [here](https://docs.python.org/2/library/itertools.html).

# %%
from itertools import combinations
combinations = list(combinations(boston.feature_names, 2))

# %%
interactions = []
for combo in combinations:
    df['interaction'] = df[combo[0]] * df[combo[1]]
    new_r_squared = np.mean(cross_val_score(regression, df, y, cv=cross_val_gen, scoring='r2'))
    print(f'New r_squared with interaction between {combo[0]} and {combo[1]}: {new_r_squared}')
    interactions.append((combo, new_r_squared))
    df.drop(columns='interaction')
# Out:
# New r_squared with interaction between CRIM and ZN: 0.7180486571803358
# New r_squared with interaction between CRIM and INDUS: 0.7180024566678995
# New r_squared with interaction between CRIM and CHAS: 0.7224266827041401
# New r_squared with interaction between CRIM and NOX: 0.720956844677177
# New r_squared with interaction between CRIM and RM: 0.7081164870054812
# New r_squared with interaction between CRIM and AGE: 0.7186385649071079
# New r_squared with interaction between CRIM and DIS: 0.7177568432378603
# New r_squared with interaction between CRIM and RAD: 0.7218426607693017
# New r_squared with interaction between CRIM and TAX: 0.7211937125038534
# New r_squared with interaction between CRIM and PTRATIO: 0.7203531457728599
# New r_squared with interaction between CRIM and B: 0.71462870277892
# New r_squared with interaction between CRIM and LSTAT: 0.7204731402012098
# New r_squared with interaction between ZN and INDUS: 0.7245130249509673
# New r_squared with interaction between ZN and CHAS: 0.7181494046844513
# New r_squared with interaction between ZN and NOX: 0.7183045979214395
# New r_squared with interaction between ZN and RM: 0.7288206411527088
# New r_squared with interaction between ZN and AGE: 0.718198864446985
# New r_squared with interaction between ZN and DIS: 0.7198623421930656
# New r_squared with interaction between ZN and RAD: 0.7183416822181867
# New r_squared with interaction between ZN and TAX: 0.7165591526708508
# New r_squared with interaction between ZN and PTRATIO: 0.7182396917152205
# New r_squared with interaction between ZN and B: 0.7178806692926938
# New r_squared with interaction between ZN and LSTAT: 0.7189128377220503
# New r_squared with interaction between INDUS and CHAS: 0.71803300236981
# New r_squared with interaction between INDUS and NOX: 0.7186439479475207
# New r_squared with interaction between INDUS and RM: 0.757780514352017
# New r_squared with interaction between INDUS and AGE: 0.7222863283271979
# New r_squared with interaction between INDUS and DIS: 0.7283635108497103
# New r_squared with interaction between INDUS and RAD: 0.7183108068285008
# New r_squared with interaction between INDUS and TAX: 0.7223792494260637
# New r_squared with interaction between INDUS and PTRATIO: 0.7182884354247878
# New r_squared with interaction between INDUS and B: 0.7180904055577042
# New r_squared with interaction between INDUS and LSTAT: 0.7193723158986447
# New r_squared with interaction between CHAS and NOX: 0.7184577020551837
# New r_squared with interaction between CHAS and RM: 0.70866048651398
# New r_squared with interaction between CHAS and AGE: 0.7177241172798564
# New r_squared with interaction between CHAS and DIS: 0.7171246240196913
# New r_squared with interaction between CHAS and RAD: 0.7199062643047318
# New r_squared with interaction between CHAS and TAX: 0.7204452777744265
# New r_squared with interaction between CHAS and PTRATIO: 0.7168977502868772
# New r_squared with interaction between CHAS and B: 0.7196376401298062
# New r_squared with interaction between CHAS and LSTAT: 0.7210130989247118
# New r_squared with interaction between NOX and RM: 0.7453599495065298
# New r_squared with interaction between NOX and AGE: 0.7178273549805467
# New r_squared with interaction between NOX and DIS: 0.7195305930076332
# New r_squared with interaction between NOX and RAD: 0.7216402620446947
# New r_squared with interaction between NOX and TAX: 0.7194683252011806
# New r_squared with interaction between NOX and PTRATIO: 0.7208556256614022
# New r_squared with interaction between NOX and B: 0.7192004212855704
# New r_squared with interaction between NOX and LSTAT: 0.7172607859057891
# New r_squared with interaction between RM and AGE: 0.740659876089026
# New r_squared with interaction between RM and DIS: 0.7342130965590978
# New r_squared with interaction between RM and RAD: 0.7682152400234057
# New r_squared with interaction between RM and TAX: 0.7750525123747647
# New r_squared with interaction between RM and PTRATIO: 0.7633759067582868
# New r_squared with interaction between RM and B: 0.738566570708287
# New r_squared with interaction between RM and LSTAT: 0.7864889421124028
# New r_squared with interaction between AGE and DIS: 0.7210193945912321
# New r_squared with interaction between AGE and RAD: 0.7169145930312515
# New r_squared with interaction between AGE and TAX: 0.7176729020685128
# New r_squared with interaction between AGE and PTRATIO: 0.719524763509534
# New r_squared with interaction between AGE and B: 0.7209442240026319
# New r_squared with interaction between AGE and LSTAT: 0.7137298809460868
# New r_squared with interaction between DIS and RAD: 0.7177953316377017
# New r_squared with interaction between DIS and TAX: 0.7188339338593158
# New r_squared with interaction between DIS and PTRATIO: 0.7212530527937469
# New r_squared with interaction between DIS and B: 0.7191799627871103
# New r_squared with interaction between DIS and LSTAT: 0.7182106823765718
# New r_squared with interaction between RAD and TAX: 0.7184832333208986
# New r_squared with interaction between RAD and PTRATIO: 0.7180755401006278
# New r_squared with interaction between RAD and B: 0.7175471138330045
# New r_squared with interaction between RAD and LSTAT: 0.716016920561812
# New r_squared with interaction between TAX and PTRATIO: 0.7220753714337282
# New r_squared with interaction between TAX and B: 0.7175783335179302
# New r_squared with interaction between TAX and LSTAT: 0.7168545256468956
# New r_squared with interaction between PTRATIO and B: 0.7187747903466472
# New r_squared with interaction between PTRATIO and LSTAT: 0.7189192431009309
# New r_squared with interaction between B and LSTAT: 0.7178930818773739

# %%
interactions.sort(key=lambda x: x[1], reverse=True)

# %%
interactions[:3]
# Out:
# [(('RM', 'LSTAT'), 0.7864889421124028),
#  (('RM', 'TAX'), 0.7750525123747647),
#  (('RM', 'RAD'), 0.7682152400234057)]

# %% [markdown]
# ## Look at the top 3 interactions: "RM" as a confounding factor

# %% [markdown]
# The top three interactions seem to involve "RM", the number of rooms as a confounding variable for all of them. Let's have a look at interaction plots for all three of them. This exercise will involve:
#
# - Splitting the data up in 3 groups: one for houses with a few rooms, one for houses with a "medium" amount of rooms, one for a high amount of rooms
# - Create a function `build_interaction_rm()`. This function takes an argument `varname` (which can be set equal to the column name as a string) and a column `description` (which describes the variable or varname, to be included on the x-axis of the plot). The function outputs a plot that uses "RM" as a confounding factor. Each plot should have three regression lines, one for each level of "RM"

# %% [markdown]
# The data has been split into high, medium, and low number of rooms for you.

# %%
rm = np.asarray(df[['RM']]).reshape(len(df[['RM']]))

# %%
target = pd.Series(y, name='target')
all_data = pd.concat([target, df], axis=1)

# %%
high_rm = all_data[rm > np.percentile(rm, 67)]
med_rm = all_data[(rm > np.percentile(rm, 33)) & (rm <= np.percentile(rm, 67))]
low_rm = all_data[rm <= np.percentile(rm, 33)]

# %% [markdown]
# Create `build_interaction_rm()`.

# %%
def build_interaction_rm(varname, description):
    regression_h = LinearRegression()
    regression_m = LinearRegression()
    regression_l = LinearRegression()
    regression_h.fit(high_rm[varname].values.reshape(-1, 1), high_rm['target'])
    regression_m.fit(med_rm[varname].values.reshape(-1, 1), med_rm['target'])
    regression_l.fit(low_rm[varname].values.reshape(-1, 1), low_rm['target'])

    # Make predictions using the testing set
    pred_high = regression_h.predict(high_rm[varname].values.reshape(-1, 1))
    pred_med = regression_m.predict(med_rm[varname].values.reshape(-1, 1))
    pred_low = regression_l.predict(low_rm[varname].values.reshape(-1, 1))

    # The coefficients
    print(regression_h.coef_)
    print(regression_m.coef_)
    print(regression_l.coef_)

    # Plot outputs
    plt.figure(figsize=(12,7))
    plt.scatter(high_rm[varname], high_rm['target'],  color='blue', alpha = 0.3, label = 'more rooms')
    plt.scatter(med_rm[varname], med_rm['target'],  color='red', alpha = 0.3, label = 'medium rooms')
    plt.scatter(low_rm[varname], low_rm['target'],  color='orange', alpha = 0.3, label = 'low amount of rooms')

    plt.plot(low_rm[varname], pred_low,  color='orange', linewidth=2)
    plt.plot(med_rm[varname], pred_med,  color='red', linewidth=2)
    plt.plot(high_rm[varname], pred_high,  color='blue', linewidth=2)
    plt.ylabel('house value')
    plt.xlabel(description)
    plt.legend()

# %% [markdown]
# Next, use `build_interaction_rm()` with the three variables that came out with the highest effect on $R^2$.

# %%
# first plot
build_interaction_rm(build_interaction_rm('LSTAT', '% of lower status'))
# Out:
# [-1.46614438]
# [-0.67588205]
# [-0.51981339]
# -------------------------------------------------------------
# TypeError                   Traceback (most recent call last)
# <ipython-input-82-61b02936bd48> in <module>
#       1 # first plot
# ----> 2 build_interaction_rm(build_interaction_rm('LSTAT', '% of lower status'))
#
# TypeError: build_interaction_rm() missing 1 required positional argument: 'description'

# %%
# second plot
build_interaction_rm('RAD','highway accessibility index')
# Out:
# [-0.66803793]
# [-0.24276834]
# [-0.17393132]

# %%
# third plot
build_interaction_rm('TAX', 'average tax rate')
# Out:
# [-0.03708037]
# [-0.01431143]
# [-0.01166035]

# %% [markdown]
# ## Build a final model including all three interactions at once

# %% [markdown]
# Use 10-fold cross-validation to build a model using all the above interactions.

# %%
# code here
regression = LinearRegression()
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)

df_inter = df.copy()
df_inter['RM_LSTAT'] = df['RM'] * df['LSTAT']
df_inter['RM_TAX'] = df['RM'] * df['TAX']
df_inter['RM_RAD'] = df['RM'] * df['RAD']

final_model = np.mean(cross_val_score(regression, df_inter, y, scoring='r2', cv=crossvalidation))

# %% [markdown]
# Our $R^2$ has increased considerably! Let's have a look in `statsmodels` to see if all these interactions are significant.

# %%
# code here
import statsmodels.api as sm
df_inter_sm = sm.add_constant(df_inter)
model = sm.OLS(y,df_inter_sm)
results = model.fit()

results.summary()
# Out:
# /home/ben/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     134.3
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):          3.25e-167
# Time:                        16:57:32   Log-Likelihood:                -1413.9
# No. Observations:                 506   AIC:                             2862.
# Df Residuals:                     489   BIC:                             2934.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -14.8453      7.428     -1.998      0.046     -29.441      -0.250
# CRIM          -0.1628      0.028     -5.756      0.000      -0.218      -0.107
# ZN             0.0174      0.012      1.463      0.144      -0.006       0.041
# INDUS          0.0900      0.053      1.707      0.088      -0.014       0.194
# CHAS           2.5988      0.740      3.511      0.000       1.144       4.053
# NOX          -13.4647      3.277     -4.109      0.000     -19.903      -7.026
# RM            10.8250      0.986     10.976      0.000       8.887      12.763
# AGE            0.0052      0.011      0.461      0.645      -0.017       0.028
# DIS           -0.9547      0.175     -5.469      0.000      -1.298      -0.612
# RAD            0.7093      0.476      1.489      0.137      -0.227       1.645
# TAX            0.0333      0.025      1.354      0.176      -0.015       0.082
# PTRATIO       -0.6849      0.113     -6.068      0.000      -0.907      -0.463
# B              0.0048      0.002      2.068      0.039       0.000       0.009
# LSTAT          1.1528      0.232      4.973      0.000       0.697       1.608
# RM_LSTAT      -0.2916      0.041     -7.169      0.000      -0.372      -0.212
# RM_TAX        -0.0072      0.004     -1.828      0.068      -0.015       0.001
# RM_RAD        -0.0699      0.078     -0.896      0.371      -0.223       0.083
# ==============================================================================
# Omnibus:                      255.231   Durbin-Watson:                   1.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2564.486
# Skew:                           1.963   Prob(JB):                         0.00
# Kurtosis:                      13.307   Cond. No.                     1.18e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# What is your conclusion here?

# %%
# formulate your conclusion

# %% [markdown]
# ## Summary

# %% [markdown]
# You should now understand how to include interaction effects in your model! As you can see, interactions can have a strong impact on linear regression models, and they should always be considered when you are constructing your models.
